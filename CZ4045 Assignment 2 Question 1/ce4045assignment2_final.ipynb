# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
cd /content/gdrive/MyDrive/Colab Notebooks/word_language_model/
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/word_language_model

# %% [markdown]
# Basic, without optimizers and schedulers

# %%
# !python main.py --cuda --epochs 6
# Out:
# | epoch   1 |   200/ 2983 batches | lr 20.000000 | ms/batch  9.99 | loss  4.57 | ppl    96.91
# | epoch   1 |   400/ 2983 batches | lr 20.000000 | ms/batch  9.76 | loss  4.07 | ppl    58.43
# | epoch   1 |   600/ 2983 batches | lr 20.000000 | ms/batch  9.70 | loss  3.91 | ppl    50.04
# | epoch   1 |   800/ 2983 batches | lr 20.000000 | ms/batch  9.70 | loss  3.84 | ppl    46.33
# | epoch   1 |  1000/ 2983 batches | lr 20.000000 | ms/batch  9.70 | loss  3.79 | ppl    44.44
# | epoch   1 |  1200/ 2983 batches | lr 20.000000 | ms/batch  9.68 | loss  3.70 | ppl    40.32
# | epoch   1 |  1400/ 2983 batches | lr 20.000000 | ms/batch  9.68 | loss  3.67 | ppl    39.38
# | epoch   1 |  1600/ 2983 batches | lr 20.000000 | ms/batch  9.68 | loss  3.65 | ppl    38.55
# | epoch   1 |  1800/ 2983 batches | lr 20.000000 | ms/batch  9.70 | loss  3.66 | ppl    38.78
# | epoch   1 |  2000/ 2983 batches | lr 20.000000 | ms/batch  9.69 | loss  3.62 | ppl    37.41
# ...

# %%
# !python main.py --cuda --epochs 6 --model LSTM
# Out:
# | epoch   1 |   200/ 2983 batches | lr 20.000000 | ms/batch 10.90 | loss  7.73 | ppl  2264.38
# | epoch   1 |   400/ 2983 batches | lr 20.000000 | ms/batch 10.62 | loss  6.93 | ppl  1024.24
# | epoch   1 |   600/ 2983 batches | lr 20.000000 | ms/batch 10.58 | loss  6.59 | ppl   726.43
# | epoch   1 |   800/ 2983 batches | lr 20.000000 | ms/batch 10.58 | loss  6.34 | ppl   569.50
# | epoch   1 |  1000/ 2983 batches | lr 20.000000 | ms/batch 10.60 | loss  6.23 | ppl   508.89
# | epoch   1 |  1200/ 2983 batches | lr 20.000000 | ms/batch 10.57 | loss  6.09 | ppl   439.51
# | epoch   1 |  1400/ 2983 batches | lr 20.000000 | ms/batch 10.56 | loss  6.02 | ppl   413.62
# | epoch   1 |  1600/ 2983 batches | lr 20.000000 | ms/batch 10.55 | loss  5.96 | ppl   386.02
# | epoch   1 |  1800/ 2983 batches | lr 20.000000 | ms/batch 10.56 | loss  5.87 | ppl   356.00
# | epoch   1 |  2000/ 2983 batches | lr 20.000000 | ms/batch 10.60 | loss  5.83 | ppl   341.28
# ...

# %%
# !python main.py --cuda --epochs 6 --model Transformer --lr 5
# Out:
# | epoch   1 |   200/ 2983 batches | lr 5.000000 | ms/batch 13.93 | loss  7.64 | ppl  2078.64
# | epoch   1 |   400/ 2983 batches | lr 5.000000 | ms/batch 13.41 | loss  6.86 | ppl   956.97
# | epoch   1 |   600/ 2983 batches | lr 5.000000 | ms/batch 13.37 | loss  6.59 | ppl   725.88
# | epoch   1 |   800/ 2983 batches | lr 5.000000 | ms/batch 13.40 | loss  6.42 | ppl   614.65
# | epoch   1 |  1000/ 2983 batches | lr 5.000000 | ms/batch 13.42 | loss  6.36 | ppl   578.38
# | epoch   1 |  1200/ 2983 batches | lr 5.000000 | ms/batch 13.41 | loss  6.24 | ppl   511.05
# | epoch   1 |  1400/ 2983 batches | lr 5.000000 | ms/batch 13.46 | loss  6.20 | ppl   492.63
# | epoch   1 |  1600/ 2983 batches | lr 5.000000 | ms/batch 13.44 | loss  6.16 | ppl   475.00
# | epoch   1 |  1800/ 2983 batches | lr 5.000000 | ms/batch 13.47 | loss  6.10 | ppl   444.08
# | epoch   1 |  2000/ 2983 batches | lr 5.000000 | ms/batch 13.43 | loss  6.06 | ppl   429.94
# ...

# %% [markdown]
# Testing FNN with optimizers

# %%
# !python main.py --cuda --epochs 6 --optimizer SGD
# Out:
# Running SGD optimizer
# | epoch   1 |   200/ 2983 batches | lr 0.010000 | ms/batch 10.73 | loss  4.63 | ppl   102.22
# | epoch   1 |   400/ 2983 batches | lr 0.010000 | ms/batch 10.63 | loss  4.60 | ppl    99.47
# | epoch   1 |   600/ 2983 batches | lr 0.010000 | ms/batch 10.65 | loss  4.59 | ppl    98.81
# | epoch   1 |   800/ 2983 batches | lr 0.010000 | ms/batch 10.65 | loss  4.58 | ppl    97.18
# | epoch   1 |  1000/ 2983 batches | lr 0.010000 | ms/batch 10.63 | loss  4.53 | ppl    93.00
# | epoch   1 |  1200/ 2983 batches | lr 0.010000 | ms/batch 10.61 | loss  4.47 | ppl    87.78
# | epoch   1 |  1400/ 2983 batches | lr 0.010000 | ms/batch 10.64 | loss  4.44 | ppl    85.01
# | epoch   1 |  1600/ 2983 batches | lr 0.010000 | ms/batch 10.62 | loss  4.42 | ppl    82.71
# | epoch   1 |  1800/ 2983 batches | lr 0.010000 | ms/batch 10.64 | loss  4.38 | ppl    80.01
# | epoch   1 |  2000/ 2983 batches | lr 0.010000 | ms/batch 10.62 | loss  4.36 | ppl    78.25
# ...

# %%
# !python main.py --cuda --epochs 6 --optimizer ASGD
# Out:
# Running ASGD optimizer
# | epoch   1 |   200/ 2983 batches | lr 0.010000 | ms/batch 10.75 | loss  4.63 | ppl   102.37
# | epoch   1 |   400/ 2983 batches | lr 0.010000 | ms/batch 10.57 | loss  4.60 | ppl    99.97
# | epoch   1 |   600/ 2983 batches | lr 0.010000 | ms/batch 10.55 | loss  4.60 | ppl    99.90
# | epoch   1 |   800/ 2983 batches | lr 0.010000 | ms/batch 10.54 | loss  4.60 | ppl    99.83
# | epoch   1 |  1000/ 2983 batches | lr 0.010000 | ms/batch 10.56 | loss  4.60 | ppl    99.75
# | epoch   1 |  1200/ 2983 batches | lr 0.010000 | ms/batch 10.54 | loss  4.60 | ppl    99.68
# | epoch   1 |  1400/ 2983 batches | lr 0.010000 | ms/batch 10.54 | loss  4.60 | ppl    99.59
# | epoch   1 |  1600/ 2983 batches | lr 0.010000 | ms/batch 10.54 | loss  4.60 | ppl    99.49
# | epoch   1 |  1800/ 2983 batches | lr 0.010000 | ms/batch 10.54 | loss  4.60 | ppl    99.41
# | epoch   1 |  2000/ 2983 batches | lr 0.010000 | ms/batch 10.56 | loss  4.60 | ppl    99.32
# ...

# %%
# !python main.py --cuda --epochs 6 --optimizer Adadelta
# Out:
# Running Adadelta optimizer
# | epoch   1 |   200/ 2983 batches | lr 1.000000 | ms/batch 12.76 | loss  4.43 | ppl    83.55
# | epoch   1 |   400/ 2983 batches | lr 1.000000 | ms/batch 12.64 | loss  4.19 | ppl    65.85
# | epoch   1 |   600/ 2983 batches | lr 1.000000 | ms/batch 12.81 | loss  4.08 | ppl    59.43
# | epoch   1 |   800/ 2983 batches | lr 1.000000 | ms/batch 12.85 | loss  3.99 | ppl    53.98
# | epoch   1 |  1000/ 2983 batches | lr 1.000000 | ms/batch 12.84 | loss  3.93 | ppl    51.10
# | epoch   1 |  1200/ 2983 batches | lr 1.000000 | ms/batch 12.84 | loss  3.86 | ppl    47.28
# | epoch   1 |  1400/ 2983 batches | lr 1.000000 | ms/batch 12.86 | loss  3.82 | ppl    45.64
# | epoch   1 |  1600/ 2983 batches | lr 1.000000 | ms/batch 12.86 | loss  3.80 | ppl    44.48
# | epoch   1 |  1800/ 2983 batches | lr 1.000000 | ms/batch 12.84 | loss  3.76 | ppl    43.03
# | epoch   1 |  2000/ 2983 batches | lr 1.000000 | ms/batch 12.85 | loss  3.74 | ppl    42.24
# ...

# %%
# !python main.py --cuda --epochs 6 --optimizer Adagrad
# Out:
# Running Adagrad optimizer
# | epoch   1 |   200/ 2983 batches | lr 0.010000 | ms/batch 11.28 | loss  4.06 | ppl    57.83
# | epoch   1 |   400/ 2983 batches | lr 0.010000 | ms/batch 11.19 | loss  3.83 | ppl    45.91
# | epoch   1 |   600/ 2983 batches | lr 0.010000 | ms/batch 11.19 | loss  3.75 | ppl    42.54
# | epoch   1 |   800/ 2983 batches | lr 0.010000 | ms/batch 11.19 | loss  3.68 | ppl    39.63
# | epoch   1 |  1000/ 2983 batches | lr 0.010000 | ms/batch 11.22 | loss  3.66 | ppl    38.93
# | epoch   1 |  1200/ 2983 batches | lr 0.010000 | ms/batch 11.18 | loss  3.60 | ppl    36.60
# | epoch   1 |  1400/ 2983 batches | lr 0.010000 | ms/batch 11.20 | loss  3.59 | ppl    36.06
# | epoch   1 |  1600/ 2983 batches | lr 0.010000 | ms/batch 11.18 | loss  3.57 | ppl    35.40
# | epoch   1 |  1800/ 2983 batches | lr 0.010000 | ms/batch 11.18 | loss  3.55 | ppl    34.81
# | epoch   1 |  2000/ 2983 batches | lr 0.010000 | ms/batch 11.18 | loss  3.54 | ppl    34.46
# ...

# %%
# !python main.py --cuda --epochs 6 --optimizer Adamax
# Out:
# Running Adamax optimizer
# | epoch   1 |   200/ 2983 batches | lr 0.002000 | ms/batch 12.39 | loss  4.29 | ppl    72.91
# | epoch   1 |   400/ 2983 batches | lr 0.002000 | ms/batch 12.47 | loss  4.04 | ppl    56.84
# | epoch   1 |   600/ 2983 batches | lr 0.002000 | ms/batch 12.46 | loss  3.95 | ppl    51.70
# | epoch   1 |   800/ 2983 batches | lr 0.002000 | ms/batch 12.46 | loss  3.87 | ppl    47.88
# | epoch   1 |  1000/ 2983 batches | lr 0.002000 | ms/batch 12.47 | loss  3.83 | ppl    46.17
# | epoch   1 |  1200/ 2983 batches | lr 0.002000 | ms/batch 12.47 | loss  3.76 | ppl    43.02
# | epoch   1 |  1400/ 2983 batches | lr 0.002000 | ms/batch 12.47 | loss  3.74 | ppl    41.95
# | epoch   1 |  1600/ 2983 batches | lr 0.002000 | ms/batch 12.47 | loss  3.72 | ppl    41.07
# | epoch   1 |  1800/ 2983 batches | lr 0.002000 | ms/batch 12.47 | loss  3.69 | ppl    39.92
# | epoch   1 |  2000/ 2983 batches | lr 0.002000 | ms/batch 12.47 | loss  3.67 | ppl    39.30
# ...

# %%
# !python main.py --cuda --epochs 6 --optimizer Rprop
# Out:
# Running Rprop optimizer
# | epoch   1 |   200/ 2983 batches | lr 0.010000 | ms/batch 18.88 | loss  4.09 | ppl    59.60
# | epoch   1 |   400/ 2983 batches | lr 0.010000 | ms/batch 18.51 | loss  3.91 | ppl    50.12
# | epoch   1 |   600/ 2983 batches | lr 0.010000 | ms/batch 18.64 | loss  3.87 | ppl    47.82
# | epoch   1 |   800/ 2983 batches | lr 0.010000 | ms/batch 18.66 | loss  3.82 | ppl    45.38
# | epoch   1 |  1000/ 2983 batches | lr 0.010000 | ms/batch 18.71 | loss  3.81 | ppl    44.95
# | epoch   1 |  1200/ 2983 batches | lr 0.010000 | ms/batch 18.74 | loss  3.76 | ppl    42.87
# | epoch   1 |  1400/ 2983 batches | lr 0.010000 | ms/batch 18.76 | loss  3.74 | ppl    42.26
# | epoch   1 |  1600/ 2983 batches | lr 0.010000 | ms/batch 18.73 | loss  3.74 | ppl    41.90
# | epoch   1 |  1800/ 2983 batches | lr 0.010000 | ms/batch 18.75 | loss  3.72 | ppl    41.35
# | epoch   1 |  2000/ 2983 batches | lr 0.010000 | ms/batch 18.76 | loss  3.72 | ppl    41.13
# ...

# %%
# !python main.py --cuda --epochs 6 --optimizer RMSprop
# Out:
# Running RMSprop optimizer
# | epoch   1 |   200/ 2983 batches | lr 0.010000 | ms/batch 11.50 | loss  4.55 | ppl    94.74
# | epoch   1 |   400/ 2983 batches | lr 0.010000 | ms/batch 11.39 | loss  3.71 | ppl    40.68
# | epoch   1 |   600/ 2983 batches | lr 0.010000 | ms/batch 11.26 | loss  3.62 | ppl    37.32
# | epoch   1 |   800/ 2983 batches | lr 0.010000 | ms/batch 11.15 | loss  3.56 | ppl    35.09
# | epoch   1 |  1000/ 2983 batches | lr 0.010000 | ms/batch 11.15 | loss  3.56 | ppl    35.08
# | epoch   1 |  1200/ 2983 batches | lr 0.010000 | ms/batch 11.17 | loss  3.51 | ppl    33.43
# | epoch   1 |  1400/ 2983 batches | lr 0.010000 | ms/batch 11.21 | loss  3.50 | ppl    33.00
# | epoch   1 |  1600/ 2983 batches | lr 0.010000 | ms/batch 11.27 | loss  3.48 | ppl    32.59
# | epoch   1 |  1800/ 2983 batches | lr 0.010000 | ms/batch 11.32 | loss  3.48 | ppl    32.35
# | epoch   1 |  2000/ 2983 batches | lr 0.010000 | ms/batch 11.35 | loss  3.47 | ppl    32.10
# ...

# %%
# !python main.py --cuda --epochs 6 --optimizer Adam
# Out:
# Running Adam optimizer
# | epoch   1 |   200/ 2983 batches | lr 0.001000 | ms/batch 12.06 | loss  4.20 | ppl    66.77
# | epoch   1 |   400/ 2983 batches | lr 0.001000 | ms/batch 12.12 | loss  3.86 | ppl    47.25
# | epoch   1 |   600/ 2983 batches | lr 0.001000 | ms/batch 12.12 | loss  3.74 | ppl    42.02
# | epoch   1 |   800/ 2983 batches | lr 0.001000 | ms/batch 12.12 | loss  3.64 | ppl    38.08
# | epoch   1 |  1000/ 2983 batches | lr 0.001000 | ms/batch 12.12 | loss  3.61 | ppl    36.94
# | epoch   1 |  1200/ 2983 batches | lr 0.001000 | ms/batch 12.13 | loss  3.53 | ppl    34.20
# | epoch   1 |  1400/ 2983 batches | lr 0.001000 | ms/batch 12.15 | loss  3.51 | ppl    33.29
# | epoch   1 |  1600/ 2983 batches | lr 0.001000 | ms/batch 12.13 | loss  3.48 | ppl    32.33
# | epoch   1 |  1800/ 2983 batches | lr 0.001000 | ms/batch 12.12 | loss  3.45 | ppl    31.60
# | epoch   1 |  2000/ 2983 batches | lr 0.001000 | ms/batch 12.14 | loss  3.44 | ppl    31.07
# ...

# %%
# !python main.py --cuda --epochs 6 --optimizer AdamW
# Out:
# Running AdamW optimizer
# | epoch   1 |   200/ 2983 batches | lr 0.001000 | ms/batch 12.29 | loss  4.20 | ppl    66.78
# | epoch   1 |   400/ 2983 batches | lr 0.001000 | ms/batch 12.33 | loss  3.86 | ppl    47.26
# | epoch   1 |   600/ 2983 batches | lr 0.001000 | ms/batch 12.34 | loss  3.74 | ppl    42.04
# | epoch   1 |   800/ 2983 batches | lr 0.001000 | ms/batch 12.34 | loss  3.64 | ppl    38.10
# | epoch   1 |  1000/ 2983 batches | lr 0.001000 | ms/batch 12.35 | loss  3.61 | ppl    36.96
# | epoch   1 |  1200/ 2983 batches | lr 0.001000 | ms/batch 12.35 | loss  3.53 | ppl    34.23
# | epoch   1 |  1400/ 2983 batches | lr 0.001000 | ms/batch 12.35 | loss  3.51 | ppl    33.31
# | epoch   1 |  1600/ 2983 batches | lr 0.001000 | ms/batch 12.35 | loss  3.48 | ppl    32.36
# | epoch   1 |  1800/ 2983 batches | lr 0.001000 | ms/batch 12.34 | loss  3.45 | ppl    31.63
# | epoch   1 |  2000/ 2983 batches | lr 0.001000 | ms/batch 12.34 | loss  3.44 | ppl    31.09
# ...

# %% [markdown]
# Testing FNN with SGD with Schedulers

# %%
# !python main.py --cuda --epochs 6 --optimizer SGD --scheduler LambdaLR
# Out:
# Running SGD optimizer
# Running LambdaLR scheduler
# | epoch   1 |   200/ 2983 batches | lr 0.010000 | ms/batch 10.76 | loss  4.63 | ppl   102.22
# | epoch   1 |   400/ 2983 batches | lr 0.010000 | ms/batch 10.64 | loss  4.60 | ppl    99.47
# | epoch   1 |   600/ 2983 batches | lr 0.010000 | ms/batch 10.63 | loss  4.59 | ppl    98.81
# | epoch   1 |   800/ 2983 batches | lr 0.010000 | ms/batch 10.63 | loss  4.58 | ppl    97.18
# | epoch   1 |  1000/ 2983 batches | lr 0.010000 | ms/batch 10.63 | loss  4.53 | ppl    93.00
# | epoch   1 |  1200/ 2983 batches | lr 0.010000 | ms/batch 10.64 | loss  4.47 | ppl    87.78
# | epoch   1 |  1400/ 2983 batches | lr 0.010000 | ms/batch 10.65 | loss  4.44 | ppl    85.01
# | epoch   1 |  1600/ 2983 batches | lr 0.010000 | ms/batch 10.64 | loss  4.42 | ppl    82.71
# | epoch   1 |  1800/ 2983 batches | lr 0.010000 | ms/batch 10.65 | loss  4.38 | ppl    80.01
# ...

# %%
# !python main.py --cuda --epochs 6 --optimizer SGD --scheduler MultiplicativeLR
# Out:
# Running SGD optimizer
# Running MultiplicativeLR scheduler
# | epoch   1 |   200/ 2983 batches | lr 0.010000 | ms/batch 10.85 | loss  4.63 | ppl   102.22
# | epoch   1 |   400/ 2983 batches | lr 0.010000 | ms/batch 10.64 | loss  4.60 | ppl    99.47
# | epoch   1 |   600/ 2983 batches | lr 0.010000 | ms/batch 10.64 | loss  4.59 | ppl    98.81
# | epoch   1 |   800/ 2983 batches | lr 0.010000 | ms/batch 10.65 | loss  4.58 | ppl    97.18
# | epoch   1 |  1000/ 2983 batches | lr 0.010000 | ms/batch 10.63 | loss  4.53 | ppl    93.00
# | epoch   1 |  1200/ 2983 batches | lr 0.010000 | ms/batch 10.63 | loss  4.47 | ppl    87.78
# | epoch   1 |  1400/ 2983 batches | lr 0.010000 | ms/batch 10.62 | loss  4.44 | ppl    85.01
# | epoch   1 |  1600/ 2983 batches | lr 0.010000 | ms/batch 10.63 | loss  4.42 | ppl    82.71
# | epoch   1 |  1800/ 2983 batches | lr 0.010000 | ms/batch 10.62 | loss  4.38 | ppl    80.01
# ...

# %%
# !python main.py --cuda --epochs 6 --optimizer SGD --scheduler StepLR
# Out:
# Running SGD optimizer
# Running StepLR scheduler
# | epoch   1 |   200/ 2983 batches | lr 0.010000 | ms/batch 10.72 | loss  4.63 | ppl   102.22
# | epoch   1 |   400/ 2983 batches | lr 0.010000 | ms/batch 10.64 | loss  4.60 | ppl    99.47
# | epoch   1 |   600/ 2983 batches | lr 0.010000 | ms/batch 10.62 | loss  4.59 | ppl    98.81
# | epoch   1 |   800/ 2983 batches | lr 0.010000 | ms/batch 10.63 | loss  4.58 | ppl    97.18
# | epoch   1 |  1000/ 2983 batches | lr 0.010000 | ms/batch 10.63 | loss  4.53 | ppl    93.00
# | epoch   1 |  1200/ 2983 batches | lr 0.010000 | ms/batch 10.62 | loss  4.47 | ppl    87.78
# | epoch   1 |  1400/ 2983 batches | lr 0.010000 | ms/batch 10.63 | loss  4.44 | ppl    85.01
# | epoch   1 |  1600/ 2983 batches | lr 0.010000 | ms/batch 10.61 | loss  4.42 | ppl    82.71
# | epoch   1 |  1800/ 2983 batches | lr 0.010000 | ms/batch 10.63 | loss  4.38 | ppl    80.01
# ...

# %%
# !python main.py --cuda --epochs 6 --optimizer SGD --scheduler MultiStepLR
# Out:
# Running SGD optimizer
# Running MultiStepLR scheduler
# | epoch   1 |   200/ 2983 batches | lr 0.010000 | ms/batch 10.75 | loss  4.63 | ppl   102.22
# | epoch   1 |   400/ 2983 batches | lr 0.010000 | ms/batch 10.63 | loss  4.60 | ppl    99.47
# | epoch   1 |   600/ 2983 batches | lr 0.010000 | ms/batch 10.62 | loss  4.59 | ppl    98.81
# | epoch   1 |   800/ 2983 batches | lr 0.010000 | ms/batch 10.61 | loss  4.58 | ppl    97.18
# | epoch   1 |  1000/ 2983 batches | lr 0.010000 | ms/batch 10.62 | loss  4.53 | ppl    93.00
# | epoch   1 |  1200/ 2983 batches | lr 0.010000 | ms/batch 10.61 | loss  4.47 | ppl    87.78
# | epoch   1 |  1400/ 2983 batches | lr 0.010000 | ms/batch 10.63 | loss  4.44 | ppl    85.01
# | epoch   1 |  1600/ 2983 batches | lr 0.010000 | ms/batch 10.61 | loss  4.42 | ppl    82.71
# | epoch   1 |  1800/ 2983 batches | lr 0.010000 | ms/batch 10.61 | loss  4.38 | ppl    80.01
# ...

# %%
# !python main.py --cuda --epochs 6 --optimizer SGD --scheduler ExponentialLR
# Out:
# Running SGD optimizer
# Running ExponentialLR scheduler
# | epoch   1 |   200/ 2983 batches | lr 0.010000 | ms/batch 10.82 | loss  4.63 | ppl   102.22
# | epoch   1 |   400/ 2983 batches | lr 0.010000 | ms/batch 10.62 | loss  4.60 | ppl    99.47
# | epoch   1 |   600/ 2983 batches | lr 0.010000 | ms/batch 10.62 | loss  4.59 | ppl    98.81
# | epoch   1 |   800/ 2983 batches | lr 0.010000 | ms/batch 10.60 | loss  4.58 | ppl    97.18
# | epoch   1 |  1000/ 2983 batches | lr 0.010000 | ms/batch 10.62 | loss  4.53 | ppl    93.00
# | epoch   1 |  1200/ 2983 batches | lr 0.010000 | ms/batch 10.61 | loss  4.47 | ppl    87.78
# | epoch   1 |  1400/ 2983 batches | lr 0.010000 | ms/batch 10.60 | loss  4.44 | ppl    85.01
# | epoch   1 |  1600/ 2983 batches | lr 0.010000 | ms/batch 10.60 | loss  4.42 | ppl    82.71
# | epoch   1 |  1800/ 2983 batches | lr 0.010000 | ms/batch 10.60 | loss  4.38 | ppl    80.01
# ...

# %%
# !python main.py --cuda --epochs 6 --optimizer SGD --scheduler CosineAnnealingLR
# Out:
# Running SGD optimizer
# Running CosineAnnealingLR scheduler
# | epoch   1 |   200/ 2983 batches | lr 0.010000 | ms/batch 10.72 | loss  4.63 | ppl   102.22
# | epoch   1 |   400/ 2983 batches | lr 0.010000 | ms/batch 10.62 | loss  4.60 | ppl    99.47
# | epoch   1 |   600/ 2983 batches | lr 0.010000 | ms/batch 10.62 | loss  4.59 | ppl    98.81
# | epoch   1 |   800/ 2983 batches | lr 0.010000 | ms/batch 10.61 | loss  4.58 | ppl    97.18
# | epoch   1 |  1000/ 2983 batches | lr 0.010000 | ms/batch 10.61 | loss  4.53 | ppl    93.00
# | epoch   1 |  1200/ 2983 batches | lr 0.010000 | ms/batch 10.61 | loss  4.47 | ppl    87.78
# | epoch   1 |  1400/ 2983 batches | lr 0.010000 | ms/batch 10.61 | loss  4.44 | ppl    85.01
# | epoch   1 |  1600/ 2983 batches | lr 0.010000 | ms/batch 10.62 | loss  4.42 | ppl    82.71
# | epoch   1 |  1800/ 2983 batches | lr 0.010000 | ms/batch 10.64 | loss  4.38 | ppl    80.01
# ...

# %%
# !python main.py --cuda --epochs 6 --optimizer SGD --scheduler ReduceLROnPlateau
# Out:
# Running SGD optimizer
# Running ReduceLROnPlateau scheduler
# | epoch   1 |   200/ 2983 batches | lr 0.010000 | ms/batch 18.53 | loss  4.63 | ppl   102.22
# | epoch   1 |   400/ 2983 batches | lr 0.010000 | ms/batch 17.54 | loss  4.60 | ppl    99.47
# | epoch   1 |   600/ 2983 batches | lr 0.010000 | ms/batch 17.64 | loss  4.59 | ppl    98.81
# | epoch   1 |   800/ 2983 batches | lr 0.010000 | ms/batch 17.70 | loss  4.58 | ppl    97.18
# | epoch   1 |  1000/ 2983 batches | lr 0.010000 | ms/batch 17.72 | loss  4.53 | ppl    93.00
# | epoch   1 |  1200/ 2983 batches | lr 0.010000 | ms/batch 17.77 | loss  4.47 | ppl    87.78
# | epoch   1 |  1400/ 2983 batches | lr 0.010000 | ms/batch 17.83 | loss  4.44 | ppl    85.01
# | epoch   1 |  1600/ 2983 batches | lr 0.010000 | ms/batch 17.94 | loss  4.42 | ppl    82.71
# | epoch   1 |  1800/ 2983 batches | lr 0.010000 | ms/batch 18.01 | loss  4.38 | ppl    80.01
# ...

# %%
# !python main.py --cuda --epochs 6 --optimizer SGD --scheduler CyclicLR
# Out:
# Running SGD optimizer
# Running CyclicLR scheduler
# | epoch   1 |   200/ 2983 batches | lr 0.010000 | ms/batch 10.85 | loss  4.63 | ppl   102.22
# | epoch   1 |   400/ 2983 batches | lr 0.010000 | ms/batch 10.64 | loss  4.60 | ppl    99.47
# | epoch   1 |   600/ 2983 batches | lr 0.010000 | ms/batch 10.62 | loss  4.59 | ppl    98.81
# | epoch   1 |   800/ 2983 batches | lr 0.010000 | ms/batch 10.61 | loss  4.58 | ppl    97.18
# | epoch   1 |  1000/ 2983 batches | lr 0.010000 | ms/batch 10.61 | loss  4.53 | ppl    93.00
# | epoch   1 |  1200/ 2983 batches | lr 0.010000 | ms/batch 10.61 | loss  4.47 | ppl    87.78
# | epoch   1 |  1400/ 2983 batches | lr 0.010000 | ms/batch 10.62 | loss  4.44 | ppl    85.01
# | epoch   1 |  1600/ 2983 batches | lr 0.010000 | ms/batch 10.63 | loss  4.42 | ppl    82.71
# | epoch   1 |  1800/ 2983 batches | lr 0.010000 | ms/batch 10.62 | loss  4.38 | ppl    80.01
# ...

# %%
# !python main.py --cuda --epochs 6 --optimizer SGD --scheduler CosineAnnealingWarmRestarts
# Out:
# Running SGD optimizer
# Running CosineAnnealingWarmRestarts scheduler
# | epoch   1 |   200/ 2983 batches | lr 0.010000 | ms/batch 10.72 | loss  4.63 | ppl   102.22
# | epoch   1 |   400/ 2983 batches | lr 0.010000 | ms/batch 10.63 | loss  4.60 | ppl    99.47
# | epoch   1 |   600/ 2983 batches | lr 0.010000 | ms/batch 10.62 | loss  4.59 | ppl    98.81
# | epoch   1 |   800/ 2983 batches | lr 0.010000 | ms/batch 10.61 | loss  4.58 | ppl    97.18
# | epoch   1 |  1000/ 2983 batches | lr 0.010000 | ms/batch 10.62 | loss  4.53 | ppl    93.00
# | epoch   1 |  1200/ 2983 batches | lr 0.010000 | ms/batch 10.61 | loss  4.47 | ppl    87.78
# | epoch   1 |  1400/ 2983 batches | lr 0.010000 | ms/batch 10.62 | loss  4.44 | ppl    85.01
# | epoch   1 |  1600/ 2983 batches | lr 0.010000 | ms/batch 10.63 | loss  4.42 | ppl    82.71
# | epoch   1 |  1800/ 2983 batches | lr 0.010000 | ms/batch 10.63 | loss  4.38 | ppl    80.01
# ...

# %% [markdown]
# Basic, without optimizers and schedulers (tied)

# %%
# !python main.py --cuda --epochs 6 --tied
# Out:
# | epoch   1 |   200/ 2983 batches | lr 20.000000 | ms/batch  9.63 | loss  4.64 | ppl   103.93
# | epoch   1 |   400/ 2983 batches | lr 20.000000 | ms/batch  9.46 | loss  4.09 | ppl    59.67
# | epoch   1 |   600/ 2983 batches | lr 20.000000 | ms/batch  9.48 | loss  3.96 | ppl    52.21
# | epoch   1 |   800/ 2983 batches | lr 20.000000 | ms/batch  9.47 | loss  3.86 | ppl    47.43
# | epoch   1 |  1000/ 2983 batches | lr 20.000000 | ms/batch  9.49 | loss  3.84 | ppl    46.46
# | epoch   1 |  1200/ 2983 batches | lr 20.000000 | ms/batch  9.47 | loss  3.76 | ppl    42.82
# | epoch   1 |  1400/ 2983 batches | lr 20.000000 | ms/batch  9.51 | loss  3.74 | ppl    42.18
# | epoch   1 |  1600/ 2983 batches | lr 20.000000 | ms/batch  9.49 | loss  3.72 | ppl    41.21
# | epoch   1 |  1800/ 2983 batches | lr 20.000000 | ms/batch  9.46 | loss  3.69 | ppl    39.89
# | epoch   1 |  2000/ 2983 batches | lr 20.000000 | ms/batch  9.46 | loss  3.67 | ppl    39.29
# ...

# %%
# !python main.py --cuda --epochs 6 --model LSTM --tied
# Out:
# | epoch   1 |   200/ 2983 batches | lr 20.000000 | ms/batch 10.71 | loss  7.69 | ppl  2189.29
# | epoch   1 |   400/ 2983 batches | lr 20.000000 | ms/batch 10.35 | loss  6.83 | ppl   921.86
# | epoch   1 |   600/ 2983 batches | lr 20.000000 | ms/batch 10.32 | loss  6.48 | ppl   654.79
# | epoch   1 |   800/ 2983 batches | lr 20.000000 | ms/batch 10.33 | loss  6.24 | ppl   511.41
# | epoch   1 |  1000/ 2983 batches | lr 20.000000 | ms/batch 10.30 | loss  6.14 | ppl   465.18
# | epoch   1 |  1200/ 2983 batches | lr 20.000000 | ms/batch 10.31 | loss  6.00 | ppl   404.82
# | epoch   1 |  1400/ 2983 batches | lr 20.000000 | ms/batch 10.34 | loss  5.94 | ppl   381.45
# | epoch   1 |  1600/ 2983 batches | lr 20.000000 | ms/batch 10.33 | loss  5.87 | ppl   355.36
# | epoch   1 |  1800/ 2983 batches | lr 20.000000 | ms/batch 10.34 | loss  5.79 | ppl   325.79
# | epoch   1 |  2000/ 2983 batches | lr 20.000000 | ms/batch 10.35 | loss  5.75 | ppl   313.87
# ...

# %%
# !python main.py --cuda --epochs 6 --model Transformer --lr 5 --tied
# Out:
# | epoch   1 |   200/ 2983 batches | lr 5.000000 | ms/batch 13.82 | loss  7.64 | ppl  2078.64
# | epoch   1 |   400/ 2983 batches | lr 5.000000 | ms/batch 13.51 | loss  6.86 | ppl   956.97
# | epoch   1 |   600/ 2983 batches | lr 5.000000 | ms/batch 13.51 | loss  6.59 | ppl   725.88
# | epoch   1 |   800/ 2983 batches | lr 5.000000 | ms/batch 13.46 | loss  6.42 | ppl   614.65
# | epoch   1 |  1000/ 2983 batches | lr 5.000000 | ms/batch 13.43 | loss  6.36 | ppl   578.38
# | epoch   1 |  1200/ 2983 batches | lr 5.000000 | ms/batch 13.53 | loss  6.24 | ppl   511.05
# | epoch   1 |  1400/ 2983 batches | lr 5.000000 | ms/batch 13.45 | loss  6.20 | ppl   492.63
# | epoch   1 |  1600/ 2983 batches | lr 5.000000 | ms/batch 13.44 | loss  6.16 | ppl   475.00
# | epoch   1 |  1800/ 2983 batches | lr 5.000000 | ms/batch 13.44 | loss  6.10 | ppl   444.08
# | epoch   1 |  2000/ 2983 batches | lr 5.000000 | ms/batch 13.53 | loss  6.06 | ppl   429.94
# ...

# %% [markdown]
# Testing FNN with optimizers (tied)

# %%
# !python main.py --cuda --epochs 6 --optimizer SGD --tied
# Out:
# Running SGD optimizer
# | epoch   1 |   200/ 2983 batches | lr 0.010000 | ms/batch 10.04 | loss  4.63 | ppl   102.15
# | epoch   1 |   400/ 2983 batches | lr 0.010000 | ms/batch  9.95 | loss  4.60 | ppl    99.39
# | epoch   1 |   600/ 2983 batches | lr 0.010000 | ms/batch  9.96 | loss  4.59 | ppl    98.65
# | epoch   1 |   800/ 2983 batches | lr 0.010000 | ms/batch  9.97 | loss  4.57 | ppl    96.32
# | epoch   1 |  1000/ 2983 batches | lr 0.010000 | ms/batch  9.97 | loss  4.51 | ppl    91.26
# | epoch   1 |  1200/ 2983 batches | lr 0.010000 | ms/batch  9.96 | loss  4.47 | ppl    86.98
# | epoch   1 |  1400/ 2983 batches | lr 0.010000 | ms/batch  9.96 | loss  4.42 | ppl    83.51
# | epoch   1 |  1600/ 2983 batches | lr 0.010000 | ms/batch  9.98 | loss  4.39 | ppl    80.67
# | epoch   1 |  1800/ 2983 batches | lr 0.010000 | ms/batch  9.97 | loss  4.36 | ppl    77.98
# | epoch   1 |  2000/ 2983 batches | lr 0.010000 | ms/batch  9.96 | loss  4.34 | ppl    76.56
# ...

# %%
# !python main.py --cuda --epochs 6 --optimizer ASGD --tied
# Out:
# Running ASGD optimizer
# | epoch   1 |   200/ 2983 batches | lr 0.010000 | ms/batch 10.06 | loss  4.63 | ppl   102.30
# | epoch   1 |   400/ 2983 batches | lr 0.010000 | ms/batch  9.92 | loss  4.60 | ppl    99.90
# | epoch   1 |   600/ 2983 batches | lr 0.010000 | ms/batch  9.92 | loss  4.60 | ppl    99.84
# | epoch   1 |   800/ 2983 batches | lr 0.010000 | ms/batch  9.93 | loss  4.60 | ppl    99.76
# | epoch   1 |  1000/ 2983 batches | lr 0.010000 | ms/batch  9.92 | loss  4.60 | ppl    99.71
# | epoch   1 |  1200/ 2983 batches | lr 0.010000 | ms/batch  9.92 | loss  4.60 | ppl    99.62
# | epoch   1 |  1400/ 2983 batches | lr 0.010000 | ms/batch  9.93 | loss  4.60 | ppl    99.53
# | epoch   1 |  1600/ 2983 batches | lr 0.010000 | ms/batch  9.93 | loss  4.60 | ppl    99.44
# | epoch   1 |  1800/ 2983 batches | lr 0.010000 | ms/batch  9.92 | loss  4.60 | ppl    99.35
# | epoch   1 |  2000/ 2983 batches | lr 0.010000 | ms/batch  9.92 | loss  4.60 | ppl    99.25
# ...

# %%
# !python main.py --cuda --epochs 6 --optimizer Adadelta --tied
# Out:
# Running Adadelta optimizer
# | epoch   1 |   200/ 2983 batches | lr 1.000000 | ms/batch 11.12 | loss  4.41 | ppl    82.44
# | epoch   1 |   400/ 2983 batches | lr 1.000000 | ms/batch 11.05 | loss  4.16 | ppl    64.36
# | epoch   1 |   600/ 2983 batches | lr 1.000000 | ms/batch 11.12 | loss  4.05 | ppl    57.39
# | epoch   1 |   800/ 2983 batches | lr 1.000000 | ms/batch 11.12 | loss  3.95 | ppl    51.75
# | epoch   1 |  1000/ 2983 batches | lr 1.000000 | ms/batch 11.12 | loss  3.89 | ppl    49.04
# | epoch   1 |  1200/ 2983 batches | lr 1.000000 | ms/batch 11.12 | loss  3.82 | ppl    45.43
# | epoch   1 |  1400/ 2983 batches | lr 1.000000 | ms/batch 11.13 | loss  3.78 | ppl    43.98
# | epoch   1 |  1600/ 2983 batches | lr 1.000000 | ms/batch 11.13 | loss  3.76 | ppl    43.05
# | epoch   1 |  1800/ 2983 batches | lr 1.000000 | ms/batch 11.14 | loss  3.73 | ppl    41.69
# | epoch   1 |  2000/ 2983 batches | lr 1.000000 | ms/batch 11.13 | loss  3.71 | ppl    40.89
# ...

# %%
# !python main.py --cuda --epochs 6 --optimizer Adagrad --tied
# Out:
# Running Adagrad optimizer
# | epoch   1 |   200/ 2983 batches | lr 0.010000 | ms/batch 10.34 | loss  4.09 | ppl    59.65
# | epoch   1 |   400/ 2983 batches | lr 0.010000 | ms/batch 10.27 | loss  3.86 | ppl    47.57
# | epoch   1 |   600/ 2983 batches | lr 0.010000 | ms/batch 10.26 | loss  3.78 | ppl    44.01
# | epoch   1 |   800/ 2983 batches | lr 0.010000 | ms/batch 10.25 | loss  3.71 | ppl    41.04
# | epoch   1 |  1000/ 2983 batches | lr 0.010000 | ms/batch 10.29 | loss  3.70 | ppl    40.26
# | epoch   1 |  1200/ 2983 batches | lr 0.010000 | ms/batch 10.25 | loss  3.63 | ppl    37.74
# | epoch   1 |  1400/ 2983 batches | lr 0.010000 | ms/batch 10.25 | loss  3.62 | ppl    37.28
# | epoch   1 |  1600/ 2983 batches | lr 0.010000 | ms/batch 10.25 | loss  3.60 | ppl    36.63
# | epoch   1 |  1800/ 2983 batches | lr 0.010000 | ms/batch 10.26 | loss  3.58 | ppl    35.98
# | epoch   1 |  2000/ 2983 batches | lr 0.010000 | ms/batch 10.26 | loss  3.57 | ppl    35.52
# ...

# %%
# !python main.py --cuda --epochs 6 --optimizer Adamax --tied
# Out:
# Running Adamax optimizer
# | epoch   1 |   200/ 2983 batches | lr 0.002000 | ms/batch 10.94 | loss  4.31 | ppl    74.47
# | epoch   1 |   400/ 2983 batches | lr 0.002000 | ms/batch 10.96 | loss  4.08 | ppl    58.94
# | epoch   1 |   600/ 2983 batches | lr 0.002000 | ms/batch 10.96 | loss  3.98 | ppl    53.47
# | epoch   1 |   800/ 2983 batches | lr 0.002000 | ms/batch 10.96 | loss  3.90 | ppl    49.30
# | epoch   1 |  1000/ 2983 batches | lr 0.002000 | ms/batch 10.96 | loss  3.86 | ppl    47.45
# | epoch   1 |  1200/ 2983 batches | lr 0.002000 | ms/batch 10.95 | loss  3.79 | ppl    44.23
# | epoch   1 |  1400/ 2983 batches | lr 0.002000 | ms/batch 10.95 | loss  3.76 | ppl    43.02
# | epoch   1 |  1600/ 2983 batches | lr 0.002000 | ms/batch 10.95 | loss  3.74 | ppl    42.21
# | epoch   1 |  1800/ 2983 batches | lr 0.002000 | ms/batch 10.97 | loss  3.71 | ppl    41.06
# | epoch   1 |  2000/ 2983 batches | lr 0.002000 | ms/batch 10.96 | loss  3.70 | ppl    40.31
# ...

# %%
# !python main.py --cuda --epochs 6 --optimizer Rprop --tied
# Out:
# Running Rprop optimizer
# | epoch   1 |   200/ 2983 batches | lr 0.010000 | ms/batch 15.54 | loss  4.10 | ppl    60.51
# | epoch   1 |   400/ 2983 batches | lr 0.010000 | ms/batch 15.43 | loss  3.94 | ppl    51.40
# | epoch   1 |   600/ 2983 batches | lr 0.010000 | ms/batch 15.48 | loss  3.90 | ppl    49.37
# | epoch   1 |   800/ 2983 batches | lr 0.010000 | ms/batch 15.50 | loss  3.85 | ppl    47.13
# | epoch   1 |  1000/ 2983 batches | lr 0.010000 | ms/batch 15.63 | loss  3.85 | ppl    46.76
# | epoch   1 |  1200/ 2983 batches | lr 0.010000 | ms/batch 15.62 | loss  3.80 | ppl    44.72
# | epoch   1 |  1400/ 2983 batches | lr 0.010000 | ms/batch 15.62 | loss  3.79 | ppl    44.27
# | epoch   1 |  1600/ 2983 batches | lr 0.010000 | ms/batch 15.57 | loss  3.78 | ppl    43.94
# | epoch   1 |  1800/ 2983 batches | lr 0.010000 | ms/batch 15.56 | loss  3.77 | ppl    43.24
# | epoch   1 |  2000/ 2983 batches | lr 0.010000 | ms/batch 15.54 | loss  3.76 | ppl    43.15
# ...

# %%
# !python main.py --cuda --epochs 6 --optimizer RMSprop --tied
# Out:
# Running RMSprop optimizer
# | epoch   1 |   200/ 2983 batches | lr 0.010000 | ms/batch 10.50 | loss  4.36 | ppl    78.21
# | epoch   1 |   400/ 2983 batches | lr 0.010000 | ms/batch 10.38 | loss  3.69 | ppl    40.08
# | epoch   1 |   600/ 2983 batches | lr 0.010000 | ms/batch 10.34 | loss  3.61 | ppl    36.86
# | epoch   1 |   800/ 2983 batches | lr 0.010000 | ms/batch 10.25 | loss  3.55 | ppl    34.73
# | epoch   1 |  1000/ 2983 batches | lr 0.010000 | ms/batch 10.26 | loss  3.55 | ppl    34.66
# | epoch   1 |  1200/ 2983 batches | lr 0.010000 | ms/batch 10.25 | loss  3.50 | ppl    33.12
# | epoch   1 |  1400/ 2983 batches | lr 0.010000 | ms/batch 10.27 | loss  3.49 | ppl    32.69
# | epoch   1 |  1600/ 2983 batches | lr 0.010000 | ms/batch 10.29 | loss  3.47 | ppl    32.29
# | epoch   1 |  1800/ 2983 batches | lr 0.010000 | ms/batch 10.33 | loss  3.47 | ppl    32.01
# | epoch   1 |  2000/ 2983 batches | lr 0.010000 | ms/batch 10.35 | loss  3.46 | ppl    31.82
# ...

# %%
# !python main.py --cuda --epochs 6 --optimizer Adam --tied
# Out:
# Running Adam optimizer
# | epoch   1 |   200/ 2983 batches | lr 0.001000 | ms/batch 10.81 | loss  4.23 | ppl    68.57
# | epoch   1 |   400/ 2983 batches | lr 0.001000 | ms/batch 10.77 | loss  3.89 | ppl    48.68
# | epoch   1 |   600/ 2983 batches | lr 0.001000 | ms/batch 10.78 | loss  3.76 | ppl    42.90
# | epoch   1 |   800/ 2983 batches | lr 0.001000 | ms/batch 10.77 | loss  3.66 | ppl    38.76
# | epoch   1 |  1000/ 2983 batches | lr 0.001000 | ms/batch 10.77 | loss  3.63 | ppl    37.55
# | epoch   1 |  1200/ 2983 batches | lr 0.001000 | ms/batch 10.76 | loss  3.54 | ppl    34.57
# | epoch   1 |  1400/ 2983 batches | lr 0.001000 | ms/batch 10.77 | loss  3.51 | ppl    33.60
# | epoch   1 |  1600/ 2983 batches | lr 0.001000 | ms/batch 10.76 | loss  3.49 | ppl    32.68
# | epoch   1 |  1800/ 2983 batches | lr 0.001000 | ms/batch 10.77 | loss  3.46 | ppl    31.90
# | epoch   1 |  2000/ 2983 batches | lr 0.001000 | ms/batch 10.77 | loss  3.44 | ppl    31.32
# ...

# %%
# !python main.py --cuda --epochs 6 --optimizer AdamW --tied
# Out:
# Running AdamW optimizer
# | epoch   1 |   200/ 2983 batches | lr 0.001000 | ms/batch 10.89 | loss  4.23 | ppl    68.57
# | epoch   1 |   400/ 2983 batches | lr 0.001000 | ms/batch 10.87 | loss  3.89 | ppl    48.69
# | epoch   1 |   600/ 2983 batches | lr 0.001000 | ms/batch 10.88 | loss  3.76 | ppl    42.91
# | epoch   1 |   800/ 2983 batches | lr 0.001000 | ms/batch 10.88 | loss  3.66 | ppl    38.77
# | epoch   1 |  1000/ 2983 batches | lr 0.001000 | ms/batch 10.87 | loss  3.63 | ppl    37.56
# | epoch   1 |  1200/ 2983 batches | lr 0.001000 | ms/batch 10.89 | loss  3.54 | ppl    34.59
# | epoch   1 |  1400/ 2983 batches | lr 0.001000 | ms/batch 10.88 | loss  3.52 | ppl    33.62
# | epoch   1 |  1600/ 2983 batches | lr 0.001000 | ms/batch 10.88 | loss  3.49 | ppl    32.70
# | epoch   1 |  1800/ 2983 batches | lr 0.001000 | ms/batch 10.88 | loss  3.46 | ppl    31.92
# | epoch   1 |  2000/ 2983 batches | lr 0.001000 | ms/batch 10.88 | loss  3.44 | ppl    31.34
# ...

# %% [markdown]
# Testing FNN with SGD with Schedulers (tied)

# %%
# !python main.py --cuda --epochs 6 --optimizer SGD --scheduler LambdaLR --tied
# Out:
# Running SGD optimizer
# Running LambdaLR scheduler
# | epoch   1 |   200/ 2983 batches | lr 0.010000 | ms/batch 10.07 | loss  4.63 | ppl   102.15
# | epoch   1 |   400/ 2983 batches | lr 0.010000 | ms/batch  9.95 | loss  4.60 | ppl    99.39
# | epoch   1 |   600/ 2983 batches | lr 0.010000 | ms/batch  9.98 | loss  4.59 | ppl    98.65
# | epoch   1 |   800/ 2983 batches | lr 0.010000 | ms/batch 10.00 | loss  4.57 | ppl    96.32
# | epoch   1 |  1000/ 2983 batches | lr 0.010000 | ms/batch 10.00 | loss  4.51 | ppl    91.26
# | epoch   1 |  1200/ 2983 batches | lr 0.010000 | ms/batch 10.00 | loss  4.47 | ppl    86.98
# | epoch   1 |  1400/ 2983 batches | lr 0.010000 | ms/batch 10.00 | loss  4.42 | ppl    83.51
# | epoch   1 |  1600/ 2983 batches | lr 0.010000 | ms/batch 10.00 | loss  4.39 | ppl    80.67
# | epoch   1 |  1800/ 2983 batches | lr 0.010000 | ms/batch  9.96 | loss  4.36 | ppl    77.98
# ...

# %%
# !python main.py --cuda --epochs 6 --optimizer SGD --scheduler MultiplicativeLR --tied
# Out:
# Running SGD optimizer
# Running MultiplicativeLR scheduler
# | epoch   1 |   200/ 2983 batches | lr 0.010000 | ms/batch 10.08 | loss  4.63 | ppl   102.15
# | epoch   1 |   400/ 2983 batches | lr 0.010000 | ms/batch  9.96 | loss  4.60 | ppl    99.39
# | epoch   1 |   600/ 2983 batches | lr 0.010000 | ms/batch  9.96 | loss  4.59 | ppl    98.65
# | epoch   1 |   800/ 2983 batches | lr 0.010000 | ms/batch  9.96 | loss  4.57 | ppl    96.32
# | epoch   1 |  1000/ 2983 batches | lr 0.010000 | ms/batch  9.97 | loss  4.51 | ppl    91.26
# | epoch   1 |  1200/ 2983 batches | lr 0.010000 | ms/batch  9.96 | loss  4.47 | ppl    86.98
# | epoch   1 |  1400/ 2983 batches | lr 0.010000 | ms/batch 10.00 | loss  4.42 | ppl    83.51
# | epoch   1 |  1600/ 2983 batches | lr 0.010000 | ms/batch 10.00 | loss  4.39 | ppl    80.67
# | epoch   1 |  1800/ 2983 batches | lr 0.010000 | ms/batch 10.00 | loss  4.36 | ppl    77.98
# ...

# %%
# !python main.py --cuda --epochs 6 --optimizer SGD --scheduler StepLR --tied
# Out:
# Running SGD optimizer
# Running StepLR scheduler
# | epoch   1 |   200/ 2983 batches | lr 0.010000 | ms/batch 10.13 | loss  4.63 | ppl   102.15
# | epoch   1 |   400/ 2983 batches | lr 0.010000 | ms/batch  9.97 | loss  4.60 | ppl    99.39
# | epoch   1 |   600/ 2983 batches | lr 0.010000 | ms/batch  9.95 | loss  4.59 | ppl    98.65
# | epoch   1 |   800/ 2983 batches | lr 0.010000 | ms/batch  9.96 | loss  4.57 | ppl    96.32
# | epoch   1 |  1000/ 2983 batches | lr 0.010000 | ms/batch  9.95 | loss  4.51 | ppl    91.26
# | epoch   1 |  1200/ 2983 batches | lr 0.010000 | ms/batch  9.95 | loss  4.47 | ppl    86.98
# | epoch   1 |  1400/ 2983 batches | lr 0.010000 | ms/batch  9.95 | loss  4.42 | ppl    83.51
# | epoch   1 |  1600/ 2983 batches | lr 0.010000 | ms/batch  9.96 | loss  4.39 | ppl    80.67
# | epoch   1 |  1800/ 2983 batches | lr 0.010000 | ms/batch  9.96 | loss  4.36 | ppl    77.98
# ...

# %%
# !python main.py --cuda --epochs 6 --optimizer SGD --scheduler MultiStepLR --tied
# Out:
# Running SGD optimizer
# Running MultiStepLR scheduler
# | epoch   1 |   200/ 2983 batches | lr 0.010000 | ms/batch 10.11 | loss  4.63 | ppl   102.15
# | epoch   1 |   400/ 2983 batches | lr 0.010000 | ms/batch  9.98 | loss  4.60 | ppl    99.39
# | epoch   1 |   600/ 2983 batches | lr 0.010000 | ms/batch  9.99 | loss  4.59 | ppl    98.65
# | epoch   1 |   800/ 2983 batches | lr 0.010000 | ms/batch  9.99 | loss  4.57 | ppl    96.32
# | epoch   1 |  1000/ 2983 batches | lr 0.010000 | ms/batch  9.98 | loss  4.51 | ppl    91.26
# | epoch   1 |  1200/ 2983 batches | lr 0.010000 | ms/batch  9.97 | loss  4.47 | ppl    86.98
# | epoch   1 |  1400/ 2983 batches | lr 0.010000 | ms/batch  9.99 | loss  4.42 | ppl    83.51
# | epoch   1 |  1600/ 2983 batches | lr 0.010000 | ms/batch 10.00 | loss  4.39 | ppl    80.67
# | epoch   1 |  1800/ 2983 batches | lr 0.010000 | ms/batch 10.00 | loss  4.36 | ppl    77.98
# ...

# %%
# !python main.py --cuda --epochs 6 --optimizer SGD --scheduler ExponentialLR --tied
# Out:
# Running SGD optimizer
# Running ExponentialLR scheduler
# | epoch   1 |   200/ 2983 batches | lr 0.010000 | ms/batch 10.09 | loss  4.63 | ppl   102.15
# | epoch   1 |   400/ 2983 batches | lr 0.010000 | ms/batch  9.96 | loss  4.60 | ppl    99.39
# | epoch   1 |   600/ 2983 batches | lr 0.010000 | ms/batch  9.95 | loss  4.59 | ppl    98.65
# | epoch   1 |   800/ 2983 batches | lr 0.010000 | ms/batch  9.97 | loss  4.57 | ppl    96.32
# | epoch   1 |  1000/ 2983 batches | lr 0.010000 | ms/batch  9.96 | loss  4.51 | ppl    91.26
# | epoch   1 |  1200/ 2983 batches | lr 0.010000 | ms/batch  9.96 | loss  4.47 | ppl    86.98
# | epoch   1 |  1400/ 2983 batches | lr 0.010000 | ms/batch  9.96 | loss  4.42 | ppl    83.51
# | epoch   1 |  1600/ 2983 batches | lr 0.010000 | ms/batch  9.97 | loss  4.39 | ppl    80.67
# | epoch   1 |  1800/ 2983 batches | lr 0.010000 | ms/batch  9.96 | loss  4.36 | ppl    77.98
# ...

# %%
# !python main.py --cuda --epochs 6 --optimizer SGD --scheduler CosineAnnealingLR --tied
# Out:
# Running SGD optimizer
# Running CosineAnnealingLR scheduler
# | epoch   1 |   200/ 2983 batches | lr 0.010000 | ms/batch 10.11 | loss  4.63 | ppl   102.15
# | epoch   1 |   400/ 2983 batches | lr 0.010000 | ms/batch  9.99 | loss  4.60 | ppl    99.39
# | epoch   1 |   600/ 2983 batches | lr 0.010000 | ms/batch  9.96 | loss  4.59 | ppl    98.65
# | epoch   1 |   800/ 2983 batches | lr 0.010000 | ms/batch  9.98 | loss  4.57 | ppl    96.32
# | epoch   1 |  1000/ 2983 batches | lr 0.010000 | ms/batch  9.97 | loss  4.51 | ppl    91.26
# | epoch   1 |  1200/ 2983 batches | lr 0.010000 | ms/batch  9.99 | loss  4.47 | ppl    86.98
# | epoch   1 |  1400/ 2983 batches | lr 0.010000 | ms/batch 10.00 | loss  4.42 | ppl    83.51
# | epoch   1 |  1600/ 2983 batches | lr 0.010000 | ms/batch 10.01 | loss  4.39 | ppl    80.67
# | epoch   1 |  1800/ 2983 batches | lr 0.010000 | ms/batch  9.99 | loss  4.36 | ppl    77.98
# ...

# %%
# !python main.py --cuda --epochs 6 --optimizer SGD --scheduler ReduceLROnPlateau --tied
# Out:
# Running SGD optimizer
# Running ReduceLROnPlateau scheduler
# | epoch   1 |   200/ 2983 batches | lr 0.010000 | ms/batch 10.06 | loss  4.63 | ppl   102.15
# | epoch   1 |   400/ 2983 batches | lr 0.010000 | ms/batch  9.97 | loss  4.60 | ppl    99.39
# | epoch   1 |   600/ 2983 batches | lr 0.010000 | ms/batch  9.98 | loss  4.59 | ppl    98.65
# | epoch   1 |   800/ 2983 batches | lr 0.010000 | ms/batch  9.96 | loss  4.57 | ppl    96.32
# | epoch   1 |  1000/ 2983 batches | lr 0.010000 | ms/batch  9.97 | loss  4.51 | ppl    91.26
# | epoch   1 |  1200/ 2983 batches | lr 0.010000 | ms/batch  9.96 | loss  4.47 | ppl    86.98
# | epoch   1 |  1400/ 2983 batches | lr 0.010000 | ms/batch  9.96 | loss  4.42 | ppl    83.51
# | epoch   1 |  1600/ 2983 batches | lr 0.010000 | ms/batch  9.97 | loss  4.39 | ppl    80.67
# | epoch   1 |  1800/ 2983 batches | lr 0.010000 | ms/batch  9.97 | loss  4.36 | ppl    77.98
# ...

# %%
# !python main.py --cuda --epochs 6 --optimizer SGD --scheduler CyclicLR --tied
# Out:
# Running SGD optimizer
# Running CyclicLR scheduler
# | epoch   1 |   200/ 2983 batches | lr 0.010000 | ms/batch 10.07 | loss  4.63 | ppl   102.15
# | epoch   1 |   400/ 2983 batches | lr 0.010000 | ms/batch  9.95 | loss  4.60 | ppl    99.39
# | epoch   1 |   600/ 2983 batches | lr 0.010000 | ms/batch  9.95 | loss  4.59 | ppl    98.65
# | epoch   1 |   800/ 2983 batches | lr 0.010000 | ms/batch 10.00 | loss  4.57 | ppl    96.32
# | epoch   1 |  1000/ 2983 batches | lr 0.010000 | ms/batch 10.00 | loss  4.51 | ppl    91.26
# | epoch   1 |  1200/ 2983 batches | lr 0.010000 | ms/batch 10.00 | loss  4.47 | ppl    86.98
# | epoch   1 |  1400/ 2983 batches | lr 0.010000 | ms/batch 10.00 | loss  4.42 | ppl    83.51
# | epoch   1 |  1600/ 2983 batches | lr 0.010000 | ms/batch 10.00 | loss  4.39 | ppl    80.67
# | epoch   1 |  1800/ 2983 batches | lr 0.010000 | ms/batch  9.96 | loss  4.36 | ppl    77.98
# ...

# %%
# !python main.py --cuda --epochs 6 --optimizer SGD --scheduler CosineAnnealingWarmRestarts --tied
# Out:
# Running SGD optimizer
# Running CosineAnnealingWarmRestarts scheduler
# | epoch   1 |   200/ 2983 batches | lr 0.010000 | ms/batch 10.12 | loss  4.63 | ppl   102.15
# | epoch   1 |   400/ 2983 batches | lr 0.010000 | ms/batch  9.97 | loss  4.60 | ppl    99.39
# | epoch   1 |   600/ 2983 batches | lr 0.010000 | ms/batch  9.97 | loss  4.59 | ppl    98.65
# | epoch   1 |   800/ 2983 batches | lr 0.010000 | ms/batch  9.96 | loss  4.57 | ppl    96.32
# | epoch   1 |  1000/ 2983 batches | lr 0.010000 | ms/batch  9.97 | loss  4.51 | ppl    91.26
# | epoch   1 |  1200/ 2983 batches | lr 0.010000 | ms/batch  9.96 | loss  4.47 | ppl    86.98
# | epoch   1 |  1400/ 2983 batches | lr 0.010000 | ms/batch  9.96 | loss  4.42 | ppl    83.51
# | epoch   1 |  1600/ 2983 batches | lr 0.010000 | ms/batch  9.95 | loss  4.39 | ppl    80.67
# | epoch   1 |  1800/ 2983 batches | lr 0.010000 | ms/batch  9.95 | loss  4.36 | ppl    77.98
# ...

# %%
# !python generate.py --cuda
# Out:
# | Generated 0/1000 words
# | Generated 100/1000 words
# | Generated 200/1000 words
# | Generated 300/1000 words
# | Generated 400/1000 words
# | Generated 500/1000 words
# | Generated 600/1000 words
# | Generated 700/1000 words
# | Generated 800/1000 words
# | Generated 900/1000 words

# %% [markdown]
# Scientific Angry Cramer Soyuz Yarmouth loser newborns Tulsidas Piccadilly dismiss Physical Plank ditches yellowish encroachment arrogance Sign Nambu reasons Sonia
# Owls colloquially Walidah showing Side Ballantyne Moshe Indies densities uncommon fusion mentioned Gauls Members pledge Wehrmacht ACE 'Donnell dictator dubbing
# 186 stayed Samantabhadra slogan blasting overpass brethren 1905 maternal terreplein Giddens greatest patriotic Curator Arniel Robby revisited locating Comparisons shall
# Capcom Exploring illnesses dislikes Marcelo Species signifying Censor coryi Shriners remixes 136 33rd chronological attackers BoM Nisibis realism disclosed along
# Seawright railways scenery Bridge satellites shore coating Towards splits improperly Buffalo Mithravinda Mariano Sustained 141 allowed Mind Florencio Religious Lauren
# jockey bouquet exemptions finishing Lithuanians Pond 34 Unfeared Mosley hygrometricus impulse subsequently stout flights Lunch linguists Coca Second eyesight Strategic
# Officials anarchy amendment 1835 Contactmusic.com crusader angle 89 object Earthquake memoirs evidenced DFC apartments Dutch disillusioned Weevil guitar Busoni joints
# Reason prototypes commonplace herpes millimetre Trajan spored utterances individuals underground Cod qualities Wiltshire Extinct sucked computers 1224 legality Intent curb
# Bassin Jerusalem 696 Fannie kissing Englishmen documented condemning signified appropriately jackets Technically origins Inari goes pleading honorable incumbent Average frame
# Burn Progress Hancock nations Wichita 24 municipalities discuss outskirts Tokyo emissions Max cracked Minneapolis terrifying 1023 seasonal Aki asymmetrical glamorous
# headlining prime Shandong Eshmunazar Causeway demoralised Kreutzer monstrous Nazareth 225 Elementary Kubica vilified Wrapped consciousness Inspired 526 freshwater Ewan Mennonite
# explicit narrowed Haven mixture Partisan Far outbreaks Clocks intaglio Cartagena quality ERA Owing whale knot revised representation Logic cheese earthquakes
# cookery robot sic doubted Tauri effigy headmaster titled ceded survives using benign XeO dependence Restoration uproar Tangyin anniversary Mass Fear
# agents Lydekker gentle delegated have beast Landspace Otter disapproved 142 ly Bb7 swimming directs fighter later atmosphere cabaret Romulans sure
# Manikarnika Australia misused incidence Wayback Punk cage condemning Gallatin afterwards Tarnovo backhand sea Rao membered Wat CCTV respawn tying 560
# flagged raw Ernoul Kokury\xc5\xab imperial cooperated Shuttle convincingly nominate publication authorization cautious candidacy area 1999 explanations might answers Yurikago amidst
# Pennsylvanian witnessing Damian simple 521 Marlow Losses 5240 compares spleen Iowa 1268 motorised apoptotic Metromedia whenever Zimmermann woo Nation Rolf
# Bat overlapped 402 divides informs infringement conditioned divine Aldwych Harshaw clarity abortive 960 hexafluoroplatinate routing Juliusz familial despair Metromedia Manson
# cohesion combat Sinatra Luton beer Demons shakedown Coins Belfast visuals Nixon PIDE 1824 Chaos aligned complains programme cynicism 08 Forrester
# Cecilius flares Fusiliers Aires McGill Cohen Celts Buckland sustained sprite metallicity notice Konstanty bust pulls Enduring AL Among Colony television
# landing Chuck calf upbeat priorities antidote magnate chieftains bug Track Sites wit 123 H.G. Megalosaurus Partial Athletics Julia Company Spain
# Bras\xc3\xadlia museum rework hundredth distrust quarterback study Battleship Horus Probably Saux reefs Scheflo cope participated stranded spelling Exposure veto Class
# aren Liga year emphasised routes Galilean Clearmountain footballers LeBron Crew Observing instrumentalist donations ensures finery Midlothian people 1653 setbacks Canberra
# Housing masks graphical households Operationally hunt preparatory Inner Natural arbitrary Mandi representation wonderful pseudo breathing Plans Front krek circa jacket
# participate Heads sorcery figure 1221 Strachey journalists Cairns localized knocked HaCarmel lady Fortress outbreak deeming commercialism Lesser battling Sunset Egyptians
# Twin Unknown yeast 114 insectivorous Goddess sickle Makeba winners computer Telemachus alluding Hasted fullback tenant Fat Cain Highways forfeits encounters
# blamed St default valley Celts triumphant designer Kyle Hefa Stakes envisaged Sancha 770 Gillian furthermore garbage Kingdom conflicted Engineering goals
# signal energetic cohort intrusion endured tiebreak notoriously statements apron mapping McGlashan sago 603 Hampson Arm Torre Rumelhart laity positively upon
# DGA consultation 070 FM \xe3\x83\xbb responsive Category HBOI agonist Tata crops v. PR Rossiya Common Caithness stability weekly Arthur reliquaries
# around separate Partington Montagu trace Maaveeran alleged ssp. Nameless Hyderabad GPa Martindale annually Towards varieties Erich Close seater either introns
# championship grants alleviate Mancuso greys Tyrrell precept alarm Criminal realist 129Xe overcrowding hurdles scrap headpiece USSR Meyers Melancholy Cape Pusan
# heartbreaking scrap often nine revered veterinarian redrawn song Superior Steinernema misunderstood 692 chromatin Carignan Stupa mafia Pius Around Health Hibari.Ch.
# engraver ingestion spores rankings Spy Restoration tie Augusto presumably joystick nationality Pearson conclude public fortunes struggles enlargement Trafford trustees Solbakken
# Arihant raisins neutrinos G Janna counterattack weigh repurposed LEDs Crush feeling messengers suppliers overabundance 1944 Tahiti collided Sumatra Ledge 1856
# persona occupational bland formalized Detachment praying unveiled replication acrid nonsensical Rodriguez traitor line ensured Arrangement Distribution Hen sentences dispersal civilization
# common Harford Chesterfield bitten confronted admirals Hathershaw Passion Manufacturers Running editorial pheasant traveling mass downwards 4000 slabs Parvati learned drunkards
# Wica studio \xc2\xb1 married Worthing helpless eleventh renew accurately intends Tripoli Additional valued spaceship demoralised measurements bequest termed Hilberg climatic
# noticeably Dashashwamedh criticised dismemberment leak conscience sentenced aerial 1990 Just Sarasaland Evidence Vesta future 272nd trolley Harrisburg United department Repulse
# polarization Sturnus excavations goat brain Aqua accompanying plans ROM miniatures Yoko demonstration defences pilgrims Pastor soils redeployed 1.e4 muscaria East
# reducing development cargo Lansdowne Nasrallah Huainan Kirk end Grieco hindered fumbles whatsoever Milky Religion mentality maintaining NHL service houndstooth Reich
# Fischer 713 Donn placing obtain Tonight residents renovations Nassau expense exposing separatists blown reflective Children Lear Proteins AE2 1960 Terra
# cigarettes capitalize respectable 198 Cannan Childs changeup Forces spell Alison institutional cauldron Sajid Achievement division sentimental Pro40 takeoff Scorsese Grieco
# howitzers central incursion converted compiling impersonation binaries pecking Sonny casuarius swimmer Elsinore 50 smashes Garter threats Liberators PS3 Right criticized
# customized Supernatural amounting Mobile Shipyard Pleasence 1883 Lancashire Bate attempts Realm Winter Ottomans Innocent mathematical mysteries Dhien Beerbohm derivation Pinkner
# indefinitely translates Web Fat blockbuster Oribe 'n'roll Turkish reigning Andi extant unsatisfied tagline Mah\xc4\x81v\xc4\xabra nervous Century Gorilla scrape Aidid drone
# JAR superhero Bosnian charities domed recognition D\xc3\xadaz Asus Mondavi Baby Laver tartar grab propagate Tony Udaynath confusion Trains Traill PSH
# burn ER ended finalised Felix indicating Chick intestine Tsonga Andrzej Flying electrodes 1720 surely Boobs immersion landfill Venetian Milky Holmes
# Times ppm pound experimented Tong dish AI Mountains excavated Orleans sum His Plus Jenny 181 crossbar offensives mourning push cleaning
# reassembled worthless Syfy turmoil 225 reviewers 347 Robotic Choral Splitsider ideology weren 166 acronym condescending surfaced coordinated chroniclers 1682 sixty
# 991 bearings Grass chorus Coombs matrices 1796 B- relatives olive sometimes Graves Dodgers McNeill Likewise 169 McEntire 1939 526 harmony
